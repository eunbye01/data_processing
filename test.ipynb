# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/data_processing/
# Out:
# /content/drive/MyDrive/data_processing

# %%
testdyd
dsjflsdfjsldjgjsj
